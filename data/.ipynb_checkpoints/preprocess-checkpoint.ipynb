# %%
import pandas as pd

child_mortality = pd.read_csv('child-mortality-gdp-per-capita.csv')
continent = pd.read_csv('continent.csv')

# %%
child_mortality
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1957
# 2        Afghanistan       AFG  1958
# 3        Afghanistan       AFG  1959
# 4        Afghanistan       AFG  1960
# ...              ...       ...   ...
# 61422       Zimbabwe       ZWE  1949
# 61423       Zimbabwe       ZWE  2019
# 61424       Zimbabwe       ZWE  2020
# 61425       Zimbabwe       ZWE  2021
# 61426  Åland Islands       ALA  2015
#
#        Child mortality (Select Gapminder, v10) (2017)  GDP per capita  \
# 0                                                 NaN             NaN
# 1                                             38.1194          1253.0
# 2                                             37.5190          1298.0
# 3                                             36.9361          1307.0
# 4                                             36.3700          1326.0
# ...                                               ...             ...
# 61422                                             NaN             NaN
# 61423                                             NaN             NaN
# 61424                                             NaN             NaN
# 61425                                             NaN             NaN
# 61426                                             NaN             NaN
#
#       417485-annotations  Population (historical estimates) Continent
# 0                    NaN                                NaN      Asia
# 1                    NaN                          8210207.0       NaN
# 2                    NaN                          8333827.0       NaN
# 3                    NaN                          8468220.0       NaN
# 4                    NaN                          8622473.0       NaN
# ...                  ...                                ...       ...
# 61422                NaN                          2681604.0       NaN
# 61423                NaN                         15354606.0       NaN
# 61424                NaN                         15669663.0       NaN
# 61425                NaN                         15993525.0       NaN
# 61426                NaN                                NaN    Europe
#
# [61427 rows x 8 columns]

# %%
continent
# Out:
#                country continent
# 0          Afghanistan      Asia
# 1              Albania    Europe
# 2              Algeria    Africa
# 3       American Samoa   Oceania
# 4              Andorra    Europe
# ..                 ...       ...
# 229  Wallis and Futuna   Oceania
# 230     Western Sahara    Africa
# 231              Yemen      Asia
# 232             Zambia    Africa
# 233           Zimbabwe    Africa
#
# [234 rows x 2 columns]

# %%
child_mortality = child_mortality[['Entity', 'Year', 'Child mortality (Select Gapminder, v10) (2017)', 'GDP per capita', 'Population (historical estimates)']]

# %%
child_mortality_2016 = child_mortality[child_mortality['Year'] == 2016]

# %%
child_mortality_2016.columns = ['country', 'year', 'child_mortality', 'gdp_per_capita', 'population']

# %%
final = pd.merge(child_mortality_2016, continent, on=['country'])
final
# Out:
#                country  year  child_mortality  gdp_per_capita  population  \
# 0          Afghanistan  2016           7.0400          1929.0  34636212.0
# 1              Albania  2016           1.3500         10342.0   2881064.0
# 2              Algeria  2016           2.5200         14331.0  40339328.0
# 3       American Samoa  2016              NaN             NaN     50468.0
# 4              Andorra  2016           0.2700             NaN     72563.0
# ..                 ...   ...              ...             ...         ...
# 217  Wallis and Futuna  2016              NaN             NaN     12086.0
# 218     Western Sahara  2016           3.6388             NaN    505461.0
# 219              Yemen  2016           5.5300          2506.0  29274010.0
# 220             Zambia  2016           6.3400          3479.0  16767758.0
# 221           Zimbabwe  2016           5.6400          1534.0  14452705.0
#
#     continent
# 0        Asia
# 1      Europe
# 2      Africa
# 3     Oceania
# 4      Europe
# ..        ...
# 217   Oceania
# 218    Africa
# 219      Asia
# 220    Africa
# 221    Africa
#
# [222 rows x 6 columns]

# %%
final.to_csv('bubble_plot.csv')
