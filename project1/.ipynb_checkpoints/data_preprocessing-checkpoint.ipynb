# %% [markdown]
# # Food waste (bubble)

# %%
import pandas as pd

# population
population = pd.read_csv("population.csv")

# gdp
gdp = pd.read_csv("gdp.csv")

# region 
region = pd.read_csv('region.csv')

# %%
## extract population and gdp details (year 2010)
population_2010 = population.iloc[:, [0, -12]] 
gdp_2010 = gdp.iloc[:, [0, -12]]

# extract region details for each country
region = region.iloc[:, [0, 2]]

# %%
# inner join based on country name (population and gdp)
merge_df = pd.merge(population_2010, gdp_2010, on='Country Name', how='inner')
merge_df.columns = ['Country', 'population', 'gdp']

# inner join based on country name (region)
merge_df = pd.merge(merge_df, region, on='Country', how='inner')

# rename columns
merge_df.columns = ['country', 'population', 'gdp', 'region']

# %%
# food waste
food_waste_2010 = pd.read_csv("food_waste.csv")

# %%
# extract required columns
food_waste_2010 = food_waste_2010[['country', 'loss_percentage']]

food_waste_2010.loc[food_waste_2010['country'].str.contains("United States of America"), 'country'] = 'United States'

# %%
# group by country and aggregate using sum operation
food_waste = food_waste_2010.groupby('country').agg('sum')

# %%
# merge food waste with population, gdp and region
final_df = pd.merge(merge_df, food_waste, on='country', how='inner')

# %%
final_df.to_csv('food_waste_donut.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Food waste (radial bar)

# %%
food_waste = pd.read_csv('food_waste_2010.csv')

# %%
food_waste['food_supply_stage'] = food_waste['food_supply_stage'].replace(['Retail'],'Retail & Wholesale')
food_waste['food_supply_stage'] = food_waste['food_supply_stage'].replace(['Wholesale'],'Retail & Wholesale')

# %%
# group by food supply stage and aggregate using sum operation
food_waste = food_waste.groupby('food_supply_stage')['loss_percentage'].agg('sum')

print(food_waste)

# %%
food_waste.to_csv('food_waste_radial.csv', encoding='utf-8', index=True)

# %% [markdown]
# # Food waste (parallel)

# %%
import pandas as pd

food_waste_cereal = pd.read_csv('food_waste_cereal.csv')
food_waste_fruit = pd.read_csv('food_waste_fruit.csv')
food_waste_other = pd.read_csv('food_waste_other.csv')
food_waste_crop = pd.read_csv('food_waste_crop.csv')
food_waste_meat = pd.read_csv('food_waste_meat.csv')

# region 
region = pd.read_csv('region.csv')

# %%
food_waste_cereal['major waste type'] = 'Cereals & Pulses'
food_waste_fruit['major waste type'] = 'Fruits & Vegetables'
food_waste_other['major waste type'] = 'Other'
food_waste_crop['major waste type'] = 'Roots, Tubers & Oil-Bearing Crops'
food_waste_meat['major waste type'] = 'Meat & Animals Products'

# %%
food_waste = pd.concat([food_waste_cereal, food_waste_fruit, food_waste_other, food_waste_crop, food_waste_meat]).reset_index(drop=True)

# %%
region = region.iloc[:, [0, 2]]

# %%
region.columns = ['country', 'Region']

# %%
# inner join based on country name (population and gdp)
merge_df = pd.merge(food_waste, region, on='country', how='inner')
merge_df
# Out:
#       m49_code   country region  cpc_code                        commodity  \
# 0          108   Burundi    NaN     111.0                            Wheat
# 1          108   Burundi    NaN     111.0                            Wheat
# 2          108   Burundi    NaN     111.0                            Wheat
# 3          108   Burundi    NaN     111.0                            Wheat
# 4          108   Burundi    NaN     112.0                     Maize (corn)
# ...        ...       ...    ...       ...                              ...
# 1152       586  Pakistan    NaN    1316.0  Mangoes, guavas and mangosteens
# 1153       586  Pakistan    NaN    1316.0  Mangoes, guavas and mangosteens
# 1154       586  Pakistan    NaN    1316.0  Mangoes, guavas and mangosteens
# 1155       586  Pakistan    NaN    1316.0  Mangoes, guavas and mangosteens
# 1156       586  Pakistan    NaN    1316.0  Mangoes, guavas and mangosteens
#
#       year  loss_percentage loss_percentage_original loss_quantity  \
# 0     2010             3.50                      3.5           NaN
# 1     2010             2.50                      2.5           NaN
# 2     2010             4.87                     4.87           NaN
# 3     2010             4.43                     4.43           NaN
# 4     2010             1.32                     1.32           NaN
# ...    ...              ...                      ...           ...
# 1152  2010             3.00                        3           NaN
# 1153  2010             4.00                        4           NaN
# 1154  2010             4.50                      4.5           NaN
# 1155  2010             3.00                        3           NaN
# 1156  2010             2.50                      2.5           NaN
#
#                  activity food_supply_stage             treatment  \
# 0     Shelling, Threshing              Farm                   NaN
# 1          Transportation              Farm                   NaN
# 2                 Storage              Farm                   NaN
# 3      Drying, Harvesting           Harvest                   NaN
# 4     Shelling, Threshing              Farm                   NaN
# ...                   ...               ...                   ...
# 1152                  NaN           Storage  At 40 degree celsius
# 1153                  NaN           Storage  At 20 degree celsius
# 1154                  NaN           Storage  At 20 degree celsius
# 1155                  NaN           Storage  At 30 degree celsius
# 1156                  NaN           Storage  At 30 degree celsius
#
#      cause_of_loss sample_size method_data_collection  \
# 0              NaN         NaN     Modelled Estimates
# 1              NaN         NaN     Modelled Estimates
# 2              NaN         NaN     Modelled Estimates
# 3              NaN         NaN     Modelled Estimates
# 4              NaN         NaN     Modelled Estimates
# ...            ...         ...                    ...
# 1152           NaN         NaN  Controlled Experiment
# 1153           NaN         NaN  Controlled Experiment
# 1154           NaN         NaN  Controlled Experiment
# 1155           NaN         NaN  Controlled Experiment
# 1156           NaN         NaN  Controlled Experiment
#
#                                               reference  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1152  M.K. Baloch, F. Bibi / South African Journal o...
# 1153  M.K. Baloch, F. Bibi / South African Journal o...
# 1154  M.K. Baloch, F. Bibi / South African Journal o...
# 1155  M.K. Baloch, F. Bibi / South African Journal o...
# 1156  M.K. Baloch, F. Bibi / South African Journal o...
#
#                                                     url  \
# 0     https://www.aphlis.net/en/page/20/data-tables#...
# 1     https://www.aphlis.net/en/page/20/data-tables#...
# 2     https://www.aphlis.net/en/page/20/data-tables#...
# 3     https://www.aphlis.net/en/page/20/data-tables#...
# 4     https://www.aphlis.net/en/page/20/data-tables#...
# ...                                                 ...
# 1152                                                NaN
# 1153                                                NaN
# 1154                                                NaN
# 1155                                                NaN
# 1156                                                NaN
#
#                                                   notes     major waste type  \
# 0                                                   NaN     Cereals & Pulses
# 1                                                   NaN     Cereals & Pulses
# 2                                                   NaN     Cereals & Pulses
# 3                                                   NaN     Cereals & Pulses
# 4                                                   NaN     Cereals & Pulses
# ...                                                 ...                  ...
# 1152  Expanded from loss factor 22415 based on the p...  Fruits & Vegetables
# 1153  Expanded from loss factor 22425 based on the p...  Fruits & Vegetables
# 1154  Expanded from loss factor 22416 based on the p...  Fruits & Vegetables
# 1155  Expanded from loss factor 22420 based on the p...  Fruits & Vegetables
# 1156  Expanded from loss factor 22426 based on the p...  Fruits & Vegetables
#
#                   Region
# 0     Sub-Saharan Africa
# 1     Sub-Saharan Africa
# 2     Sub-Saharan Africa
# 3     Sub-Saharan Africa
# 4     Sub-Saharan Africa
# ...                  ...
# 1152          South Asia
# 1153          South Asia
# 1154          South Asia
# 1155          South Asia
# 1156          South Asia
#
# [1157 rows x 20 columns]

# %%
merge_df.to_csv('food_waste_parallel.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Food waste (alluvial - stage)

# %%
import pandas as pd

food_waste = pd.read_csv('food_waste_parallel.csv')
food_waste['food_supply_stage'] = food_waste['food_supply_stage'].replace(['Retail'],'Retail & Wholesale')
food_waste['food_supply_stage'] = food_waste['food_supply_stage'].replace(['Wholesale'],'Retail & Wholesale')

# %%
food_waste = food_waste.drop(food_waste[food_waste['major waste type'].str.contains('Cereals & Pulses') & food_waste['food_supply'].sample(frac=.3).index)
# Out:
#   Input In [103]
#     food_waste = food_waste.drop(food_waste[food_waste['major waste type'].str.contains('Cereals & Pulses') & food_waste['food_supply'].sample(frac=.3).index)
#                                                                                                                                                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
food_waste.to_csv('food_waste_alluvial.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Food waste (alluvial - region)

# %%
import pandas as pd

food_waste = pd.read_csv('food_waste_line.csv')
region = pd.read_csv('region.csv')

food_waste_cereal = pd.read_csv('food_waste_cereal_1980.csv')
food_waste_fruit = pd.read_csv('food_waste_fruit_1980.csv')
food_waste_other = pd.read_csv('food_waste_other_1980.csv')
food_waste_crop = pd.read_csv('food_waste_crop_1980.csv')
food_waste_meat = pd.read_csv('food_waste_meat_1980.csv')

# %%
food_waste_cereal['major waste type'] = 'Cereals & Pulses'
food_waste_fruit['major waste type'] = 'Fruits & Vegetables'
food_waste_other['major waste type'] = 'Other'
food_waste_crop['major waste type'] = 'Roots, Tubers & Oil-Bearing Crops'
food_waste_meat['major waste type'] = 'Meat & Animals Products'

# %%
food_waste = pd.concat([food_waste_cereal, food_waste_fruit, food_waste_other, food_waste_crop, food_waste_meat]).reset_index(drop=True)

# %%
region = region.iloc[:, [0, 2]]
region.columns = ['country', 'Region']

# %%
# inner join based on country name 
merge_df = pd.merge(food_waste, region, on='country', how='inner')
merge_df
# Out:
#        m49_code               country region  cpc_code       commodity  year  \
# 0           104               Myanmar    NaN     113.0            Rice  1994
# 1           104               Myanmar    NaN     113.0            Rice  1994
# 2           104               Myanmar    NaN     113.0            Rice  1994
# 3           104               Myanmar    NaN     113.0            Rice  1994
# 4           104               Myanmar    NaN     113.0            Rice  1994
# ...         ...                   ...    ...       ...             ...   ...
# 10689       604                  Peru    NaN    1510.0        Potatoes  1991
# 10690       604                  Peru    NaN    1510.0        Potatoes  1991
# 10691       688                Serbia    NaN    1445.0  Sunflower seed  2009
# 10692       688                Serbia    NaN    1445.0  Sunflower seed  2008
# 10693       760  Syrian Arab Republic    NaN    1510.0        Potatoes  1991
#
#        loss_percentage loss_percentage_original loss_quantity    activity  \
# 0                 2.10                      2.1           NaN         NaN
# 1                 0.50                      0.5           NaN         NaN
# 2                 5.20                      5.2           NaN         NaN
# 3                 1.90                      1.9           NaN         NaN
# 4                 2.10                      2.1           NaN  Harvesting
# ...                ...                      ...           ...         ...
# 10689            50.00                       50           NaN         NaN
# 10690            15.15                 3.1-27.2           NaN         NaN
# 10691             5.00                        5           NaN         NaN
# 10692             5.00                        5           NaN         NaN
# 10693            10.00                       10           NaN         NaN
#
#         food_supply_stage                   treatment  \
# 0                 Harvest                         NaN
# 1                    Farm                         NaN
# 2                    Farm                         NaN
# 3                 Harvest                         NaN
# 4                 Harvest                         NaN
# ...                   ...                         ...
# 10689             Storage                         NaN
# 10690           Wholesale                         NaN
# 10691         Pre-harvest  on zero pre-herbicide plot
# 10692         Pre-harvest  on zero pre-herbicide plot
# 10693  Whole supply chain                         NaN
#
#                                            cause_of_loss sample_size  \
# 0                        Too Mature, Leading To Breakage         NaN
# 1                            Field Stacking And Bundling         NaN
# 2                                          Reaper-Binder         NaN
# 3                               Traditional Hand Cutting         NaN
# 4                                      Combine-Harvester         NaN
# ...                                                  ...         ...
# 10689                       an improved storage facility         NaN
# 10690  Rottenness, Weight loss, Contusions, Greening,...         NaN
# 10691                                               weed         NaN
# 10692                                               weed         NaN
# 10693                                                NaN         NaN
#
#              method_data_collection  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 10689                Expert Opinion
# 10690                Expert Opinion
# 10691         Controlled Experiment
# 10692         Controlled Experiment
# 10693  No Data Collection Specified
#
#                                                reference  \
# 0                                                    NaN
# 1                                                    NaN
# 2      (Calverley: evaluation of 11 FAO projects in A...
# 3      (Calverley: evaluation of 11 FAO projects in A...
# 4      (Calverley: evaluation of 11 FAO projects in A...
# ...                                                  ...
# 10689                                                NaN
# 10690               : Brandes Salazar; Dazzy et al, 1997
# 10691                 Elsevier field crop research, 2012
# 10692                 Elsevier field crop research, 2012
# 10693                                    CIP. FAO, 1995.
#
#                                                      url  \
# 0      http://www.fao.org/docrep/004/ac301e/AC301e04....
# 1      http://www.fao.org/docrep/004/ac301e/AC301e04....
# 2      http://www.fao.org/docrep/004/ac301e/AC301e04....
# 3      http://www.fao.org/docrep/004/ac301e/AC301e04....
# 4      http://www.fao.org/docrep/004/ac301e/AC301e04....
# ...                                                  ...
# 10689                  http://www.fao.org/3/a-ax440e.pdf
# 10690                  http://www.fao.org/3/a-ax440e.pdf
# 10691  https://linkinghub.elsevier.com/retrieve/pii/S...
# 10692  https://linkinghub.elsevier.com/retrieve/pii/S...
# 10693                  http://www.fao.org/3/a-ax440e.pdf
#
#                                                    notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10689                                                NaN
# 10690                                                NaN
# 10691  Expanded from loss factor 22312 based on the p...
# 10692  Expanded from loss factor 22312 based on the p...
# 10693                                                NaN
#
#                         major waste type                      Region
# 0                       Cereals & Pulses         East Asia & Pacific
# 1                       Cereals & Pulses         East Asia & Pacific
# 2                       Cereals & Pulses         East Asia & Pacific
# 3                       Cereals & Pulses         East Asia & Pacific
# 4                       Cereals & Pulses         East Asia & Pacific
# ...                                  ...                         ...
# 10689  Roots, Tubers & Oil-Bearing Crops   Latin America & Caribbean
# 10690  Roots, Tubers & Oil-Bearing Crops   Latin America & Caribbean
# 10691  Roots, Tubers & Oil-Bearing Crops       Europe & Central Asia
# 10692  Roots, Tubers & Oil-Bearing Crops       Europe & Central Asia
# 10693  Roots, Tubers & Oil-Bearing Crops  Middle East & North Africa
#
# [10694 rows x 20 columns]

# %%
merge_df = merge_df.drop(merge_df[merge_df['Region'].str.contains('Europe & Central Asia') & merge_df['major waste type'].str.contains('Cereals & Pulses')].sample(frac=.3).index)

# %%
merge_df.to_csv('food_waste_alluvial_region.csv', encoding='utf-8', index=False)
